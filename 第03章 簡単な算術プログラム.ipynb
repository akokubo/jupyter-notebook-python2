# %% [markdown]
# p.25

# %%
import datetime

# %%
# 完全立方に対する立方根を求める
x = int(raw_input('Enter an integer:'))

beginDate = datetime.datetime.now()

ans = 0
while ans ** 3 < abs(x):
    ans = ans + 1 # 1つずつ増やす
if ans ** 3 != abs(x):
    print x + 'は完全立方ではありません'
else:
    if x < 0:
        ans = -ans
    print str(x) + 'の立方根は' + str(ans) + 'です'

endDate = datetime.datetime.now()
print "経過時間: " + str(endDate - beginDate)
# Out:
# Enter an integer:1957816251
# 1957816251の立方根は1251です
# 経過時間: 0:00:00.001242

# %%
# 完全立方に対する立方根を求める
x = int(raw_input('Enter an integer:'))

beginDate = datetime.datetime.now()

ans = 0
while ans ** 3 < abs(x):
    ans = ans + 1 # 1つずつ増やす
if ans ** 3 != abs(x):
    print x + 'は完全立方ではありません'
else:
    if x < 0:
        ans = -ans
    print str(x) + 'の立方根は' + str(ans) + 'です'

endDate = datetime.datetime.now()
print "経過時間: " + str(endDate - beginDate)
# Out:
# Enter an integer:7406961012236344616
# 7406961012236344616の立方根は1949306です
# 経過時間: 0:00:00.588775

# %% [raw]
# p.26

# %%
# 完全立方に対する立方根を求める
x = int(raw_input('Enter an integer:'))
ans = 0
while ans ** 3 < abs(x):
    print '減少関数「abs(x)-ans**3」の値は' + str(abs(x) - ans ** 3)
    ans = ans
if ans**3 != abs(x):
    print x + 'は完全立方ではありません'
else:
    if x < 0:
        ans = -ans
    print str(x) + 'の立方根は' + str(ans) + 'です'
# Out:
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# 減少関数「abs(x)-ans**3」の値は1957816251
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c61aed23c4b9> in <module>()
#       3 ans = 0
#       4 while ans ** 3 < abs(x):
# ----> 5     print '減少関数「abs(x)-ans**3」の値は' + str(abs(x) - ans ** 3)
#       6     ans = ans
#       7 if ans**3 != abs(x):
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     374             is_child = (not self._is_master_process())
#     375             # only touch the buffer in the IO thread to avoid races
# --> 376             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     377             if is_child:
#     378                 # newlines imply flush in subprocesses
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/ipykernel/iostream.pyc in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/zmq/sugar/socket.pyc in send(self, data, flags, copy, track, routing_id, group)
#     389                                  copy_threshold=self.copy_threshold)
#     390             data.group = group
# --> 391         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     392
#     393     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#      10     """
#      11     cdef int errno = zmq_errno()
# ---> 12     PyErr_CheckSignals()
#      13     if rc == -1: # if rc < -1, it's a bug in libzmq. Should we warn?
#      14         if errno == EINTR:
#
# KeyboardInterrupt:

# %% [raw]
# p.27

# %%
maxValue = int(raw_input('Enter a positive integer:'))

beginDate = datetime.datetime.now()

i = 0
while i < maxValue:
    i = i + 1
print i

endDate = datetime.datetime.now()
print "経過時間: " + str(endDate - beginDate)
# Out:
# Enter a positive integer:1000000000
# 1000000000
# 経過時間: 0:02:53.618844

# %%
# 指練習
num = int(raw_input('Enter a positive integer:'))
find = False # 解が見つかったか否か(解が必ず見つかるなら不要)
pwr = 1
while pwr <= 5:
    root = 1
    while root <= num:
        if num == root ** pwr:
            print str(num) + '=' + str(root) + '**' + str(pwr)
            find = True
        root = root + 1
    pwr = pwr + 1
if find == False:
    print str(num) + '=root**pwrとなるrootとpwrの組はありませんでした'
# Out:
# Enter a positive integer:6561
# 6561=6561**1
# 6561=81**2
# 6561=9**4

# %% [raw]
# p.28

# %%
x = 4
for i in range(0, x):
    print i
# Out:
# 0
# 1
# 2
# 3

# %%
x = 4
for i in range(0, x):
    print i
    x = 5
# Out:
# 0
# 1
# 2
# 3

# %%
x = 4
for j in range(x):
    for i in range(x):
        print i
        x = 2
# Out:
# 0
# 1
# 2
# 3
# 0
# 1
# 0
# 1
# 0
# 1

# %% [raw]
# p.29

# %%
# 完全立方に対する立方根を求める
x = int(raw_input('Enter an integer:'))

beginDate = datetime.datetime.now()

for ans in range(0, abs(x) + 1): # 0からabs(x)の間に答えがあるはず
    if ans ** 3 >= abs(x):
        break
if ans ** 3 != abs(x):
    print x + 'は完全立方ではありません'
else:
    if x < 0:
        ans = -ans
    print str(x) + 'の立方根は' + str(ans) + 'です'

endDate = datetime.datetime.now()
print "経過時間: " + str(endDate - beginDate)
# Out:
# Enter an integer:1957816251
# 1957816251の立方根は1251です
# 経過時間: 0:04:04.187964

# %%
total = 0
for c in '123456789':
    total = total + int(c)
    print total
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
# 指練習 floatを使用する場合
s = '1.23,2.4,3.123' # 入力文字列
total = 0 # 合計
num = '' # 一時的に部分文字列を保存
for c in s:
    if c != ',': # ','でなければ
        # その文字を部分文字列へ追加する
        num = num + c
    else: # ','であれば
        if num != '': # 部分文字列が空でなければ(イレギュラーな入力をスルー)
            # 部分文字列を小数に変換して合計に加える
            total = total + float(num)
            # 部分文字列を空にする
            num = ''
# 最後の部分文字列を処理する
if num != '':
    total = total + float(num)
print total
# Out:
# 6.753

# %%
# 指練習 floatを使用しない場合
s = '1.23,2.4,3.123'
total = 0
state = '整数部' # 現在解析しているのが整数部か小数部か
power = 0 # 指数部
num = ''
for c in s:
    if c == ',':
        if num != '':
            total = total + int(num) * (10 ** power)
            num = ''
            state = '整数部'
            power = 0
    elif state == '整数部':
        if c == '.':
            state = '小数部'
        else:
            num += num + c
    else: # 小数部を解析しているとき
        num = num + c
        power -= 1

# 最後の部分文字列を処理する
if num != '':
    total = total + int(num) * (10**power)
print total
# Out:
# 6.753

# %% [raw]
# p.30

# %%
x = 25 # 平方根を求めたい数

epsilon = 0.01 # 精度
step = epsilon**2 # 探索の刻み
numGuesses = 0 # 試行回数
ans = 0 # 近似解
while abs(ans ** 2 - x) >= epsilon and ans <= x:
    ans += step
    numGuesses += 1
print '試行回数=' + str(numGuesses)

if abs(ans**2 - x) >= epsilon:
    print str(x) + 'の平方根を見つけられませんでした'
else:
    print str(x) + 'の平方根の近似解は' + str(ans) +'です'
# Out:
# 試行回数=49990
# 25の平方根の近似解は4.999です

# %%
x = 0.25 # 平方根を求めたい数

epsilon = 0.01 # 精度
step = epsilon**2 # 探索の刻み
numGuesses = 0 # 試行回数
ans = 0 # 近似解
while abs(ans ** 2 - x) >= epsilon and ans <= x:
    ans += step
    numGuesses += 1
print '試行回数=' + str(numGuesses)

if abs(ans**2 - x) >= epsilon:
    print str(x) + 'の平方根を見つけられませんでした'
else:
    print str(x) + 'の平方根の近似解は' + str(ans) +'です'
# Out:
# 試行回数=2501
# 0.25の平方根を見つけられませんでした

# %%
x = 0.25 # 平方根を求めたい数

epsilon = 0.01 # 精度
step = epsilon**2 # 探索の刻み
numGuesses = 0 # 試行回数
ans = 0 # 近似解
while abs(ans ** 2 - x) >= epsilon and ans * ans <= x:
    ans += step
    numGuesses += 1
print '試行回数=' + str(numGuesses)

if abs(ans**2 - x) >= epsilon:
    print str(x) + 'の平方根を見つけられませんでした'
else:
    print str(x) + 'の平方根の近似解は' + str(ans) +'です'
# Out:
# 試行回数=4899
# 0.25の平方根の近似解は0.4899です

# %% [raw]
# p.31

# %%
x = 3513631 # 平方根を求めたい数

epsilon = 0.01 # 精度
step = epsilon**2 # 探索の刻み
numGuesses = 0 # 試行回数
ans = 0 # 近似解
while abs(ans ** 2 - x) >= epsilon and ans * ans <= x:
    ans += step
    numGuesses += 1
print '試行回数=' + str(numGuesses)

if abs(ans**2 - x) >= epsilon:
    print str(x) + 'の平方根を見つけられませんでした'
else:
    print str(x) + 'の平方根の近似解は' + str(ans) +'です'
# Out:
# 試行回数=18744682
# 3513631の平方根を見つけられませんでした

# %% [raw]
# p.32

# %%
x = 25.0
epsilon = 0.01
numGuesses = 0
low = 0.0
high = max(1.0, x) # xが1以下なら平方根はxより大きくなるから
ans = (high + low) / 2.0
while abs(ans ** 2 - x) >= epsilon:
    print '下限 =', low, '上限 =', high, '解 =', ans
    numGuesses += 1
    if ans**2 < x:
        low = ans
    else:
        high = ans
    ans = (high + low) / 2.0

print '試行回数 =' + str(numGuesses)
print str(x) + 'の平方根の近似解は' + str(ans)
# Out:
# 下限 = 0.0 上限 = 25.0 解 = 12.5
# 下限 = 0.0 上限 = 12.5 解 = 6.25
# 下限 = 0.0 上限 = 6.25 解 = 3.125
# 下限 = 3.125 上限 = 6.25 解 = 4.6875
# 下限 = 4.6875 上限 = 6.25 解 = 5.46875
# 下限 = 4.6875 上限 = 5.46875 解 = 5.078125
# 下限 = 4.6875 上限 = 5.078125 解 = 4.8828125
# 下限 = 4.8828125 上限 = 5.078125 解 = 4.98046875
# 下限 = 4.98046875 上限 = 5.078125 解 = 5.029296875
# 下限 = 4.98046875 上限 = 5.029296875 解 = 5.0048828125
# 下限 = 4.98046875 上限 = 5.0048828125 解 = 4.99267578125
# 下限 = 4.99267578125 上限 = 5.0048828125 解 = 4.99877929688
# 下限 = 4.99877929688 上限 = 5.0048828125 解 = 5.00183105469
# 試行回数 =13
# 25.0の平方根の近似解は5.00030517578

# %% [raw]
# p.33

# %%
# 指練習
x = -257
epsilon = 0.01
numGuesses = 0
low = 0.0
high = max(1.0, x) # xが1以下なら平方根はxより大きくなるから
ans = (high + low) / 2.0
while abs(ans ** 2 - x) >= epsilon:
    print '下限 =', low, '上限 =', high, '解 =', ans
    numGuesses += 1
    if ans**2 < x:
        low = ans
    else:
        high = ans
    ans = (high + low) / 2.0

print '試行回数 =' + str(numGuesses)
print str(x) + 'の平方根の近似解は' + str(ans)
# Out:
# 下限 = 0.0 上限 = 1.0 解 = 0.5
# 下限 = 0.0 上限 = 0.5 解 = 0.25
# 下限 = 0.0 上限 = 0.25 解 = 0.125
# 下限 = 0.0 上限 = 0.125 解 = 0.0625
# 下限 = 0.0 上限 = 0.0625 解 = 0.03125
# 下限 = 0.0 上限 = 0.03125 解 = 0.015625
# 下限 = 0.0 上限 = 0.015625 解 = 0.0078125
# 下限 = 0.0 上限 = 0.0078125 解 = 0.00390625
# 下限 = 0.0 上限 = 0.00390625 解 = 0.001953125
# 下限 = 0.0 上限 = 0.001953125 解 = 0.0009765625
# 下限 = 0.0 上限 = 0.0009765625 解 = 0.00048828125
# 下限 = 0.0 上限 = 0.00048828125 解 = 0.000244140625
# 下限 = 0.0 上限 = 0.000244140625 解 = 0.0001220703125
# 下限 = 0.0 上限 = 0.0001220703125 解 = 6.103515625e-05
# 下限 = 0.0 上限 = 6.103515625e-05 解 = 3.0517578125e-05
# 下限 = 0.0 上限 = 3.0517578125e-05 解 = 1.52587890625e-05
# 下限 = 0.0 上限 = 1.52587890625e-05 解 = 7.62939453125e-06
# 下限 = 0.0 上限 = 7.62939453125e-06 解 = 3.81469726562e-06
# 下限 = 0.0 上限 = 3.81469726562e-06 解 = 1.90734863281e-06
# 下限 = 0.0 上限 = 1.90734863281e-06 解 = 9.53674316406e-07
# 下限 = 0.0 上限 = 9.53674316406e-07 解 = 4.76837158203e-07
# 下限 = 0.0 上限 = 4.76837158203e-07 解 = 2.38418579102e-07
# 下限 = 0.0 上限 = 2.38418579102e-07 解 = 1.19209289551e-07
# 下限 = 0.0 上限 = 1.19209289551e-07 解 = 5.96046447754e-08
# 下限 = 0.0 上限 = 5.96046447754e-08 解 = 2.98023223877e-08
# 下限 = 0.0 上限 = 2.98023223877e-08 解 = 1.49011611938e-08
# 下限 = 0.0 上限 = 1.49011611938e-08 解 = 7.45058059692e-09
# 下限 = 0.0 上限 = 7.45058059692e-09 解 = 3.72529029846e-09
# 下限 = 0.0 上限 = 3.72529029846e-09 解 = 1.86264514923e-09
# 下限 = 0.0 上限 = 1.86264514923e-09 解 = 9.31322574615e-10
# 下限 = 0.0 上限 = 9.31322574615e-10 解 = 4.65661287308e-10
# 下限 = 0.0 上限 = 4.65661287308e-10 解 = 2.32830643654e-10
# 下限 = 0.0 上限 = 2.32830643654e-10 解 = 1.16415321827e-10
# 下限 = 0.0 上限 = 1.16415321827e-10 解 = 5.82076609135e-11
# 下限 = 0.0 上限 = 5.82076609135e-11 解 = 2.91038304567e-11
# 下限 = 0.0 上限 = 2.91038304567e-11 解 = 1.45519152284e-11
# 下限 = 0.0 上限 = 1.45519152284e-11 解 = 7.27595761418e-12
# 下限 = 0.0 上限 = 7.27595761418e-12 解 = 3.63797880709e-12
# 下限 = 0.0 上限 = 3.63797880709e-12 解 = 1.81898940355e-12
# 下限 = 0.0 上限 = 1.81898940355e-12 解 = 9.09494701773e-13
# 下限 = 0.0 上限 = 9.09494701773e-13 解 = 4.54747350886e-13
# 下限 = 0.0 上限 = 4.54747350886e-13 解 = 2.27373675443e-13
# 下限 = 0.0 上限 = 2.27373675443e-13 解 = 1.13686837722e-13
# 下限 = 0.0 上限 = 1.13686837722e-13 解 = 5.68434188608e-14
# 下限 = 0.0 上限 = 5.68434188608e-14 解 = 2.84217094304e-14
# 下限 = 0.0 上限 = 2.84217094304e-14 解 = 1.42108547152e-14
# 下限 = 0.0 上限 = 1.42108547152e-14 解 = 7.1054273576e-15
# 下限 = 0.0 上限 = 7.1054273576e-15 解 = 3.5527136788e-15
# 下限 = 0.0 上限 = 3.5527136788e-15 解 = 1.7763568394e-15
# 下限 = 0.0 上限 = 1.7763568394e-15 解 = 8.881784197e-16
# 下限 = 0.0 上限 = 8.881784197e-16 解 = 4.4408920985e-16
# 下限 = 0.0 上限 = 4.4408920985e-16 解 = 2.22044604925e-16
# 下限 = 0.0 上限 = 2.22044604925e-16 解 = 1.11022302463e-16
# 下限 = 0.0 上限 = 1.11022302463e-16 解 = 5.55111512313e-17
# 下限 = 0.0 上限 = 5.55111512313e-17 解 = 2.77555756156e-17
# 下限 = 0.0 上限 = 2.77555756156e-17 解 = 1.38777878078e-17
# 下限 = 0.0 上限 = 1.38777878078e-17 解 = 6.93889390391e-18
# 下限 = 0.0 上限 = 6.93889390391e-18 解 = 3.46944695195e-18
# 下限 = 0.0 上限 = 3.46944695195e-18 解 = 1.73472347598e-18
# 下限 = 0.0 上限 = 1.73472347598e-18 解 = 8.67361737988e-19
# 下限 = 0.0 上限 = 8.67361737988e-19 解 = 4.33680868994e-19
# 下限 = 0.0 上限 = 4.33680868994e-19 解 = 2.16840434497e-19
# 下限 = 0.0 上限 = 2.16840434497e-19 解 = 1.08420217249e-19
# 下限 = 0.0 上限 = 1.08420217249e-19 解 = 5.42101086243e-20
# 下限 = 0.0 上限 = 5.42101086243e-20 解 = 2.71050543121e-20
# 下限 = 0.0 上限 = 2.71050543121e-20 解 = 1.35525271561e-20
# 下限 = 0.0 上限 = 1.35525271561e-20 解 = 6.77626357803e-21
# 下限 = 0.0 上限 = 6.77626357803e-21 解 = 3.38813178902e-21
# 下限 = 0.0 上限 = 3.38813178902e-21 解 = 1.69406589451e-21
# 下限 = 0.0 上限 = 1.69406589451e-21 解 = 8.47032947254e-22
# 下限 = 0.0 上限 = 8.47032947254e-22 解 = 4.23516473627e-22
# 下限 = 0.0 上限 = 4.23516473627e-22 解 = 2.11758236814e-22
# 下限 = 0.0 上限 = 2.11758236814e-22 解 = 1.05879118407e-22
# 下限 = 0.0 上限 = 1.05879118407e-22 解 = 5.29395592034e-23
# 下限 = 0.0 上限 = 5.29395592034e-23 解 = 2.64697796017e-23
# 下限 = 0.0 上限 = 2.64697796017e-23 解 = 1.32348898008e-23
# 下限 = 0.0 上限 = 1.32348898008e-23 解 = 6.61744490042e-24
# 下限 = 0.0 上限 = 6.61744490042e-24 解 = 3.30872245021e-24
# 下限 = 0.0 上限 = 3.30872245021e-24 解 = 1.65436122511e-24
# 下限 = 0.0 上限 = 1.65436122511e-24 解 = 8.27180612553e-25
# 下限 = 0.0 上限 = 8.27180612553e-25 解 = 4.13590306277e-25
# 下限 = 0.0 上限 = 4.13590306277e-25 解 = 2.06795153138e-25
# 下限 = 0.0 上限 = 2.06795153138e-25 解 = 1.03397576569e-25
# 下限 = 0.0 上限 = 1.03397576569e-25 解 = 5.16987882846e-26
# 下限 = 0.0 上限 = 5.16987882846e-26 解 = 2.58493941423e-26
# 下限 = 0.0 上限 = 2.58493941423e-26 解 = 1.29246970711e-26
# 下限 = 0.0 上限 = 1.29246970711e-26 解 = 6.46234853557e-27
# 下限 = 0.0 上限 = 6.46234853557e-27 解 = 3.23117426779e-27
# 下限 = 0.0 上限 = 3.23117426779e-27 解 = 1.61558713389e-27
# 下限 = 0.0 上限 = 1.61558713389e-27 解 = 8.07793566946e-28
# 下限 = 0.0 上限 = 8.07793566946e-28 解 = 4.03896783473e-28
# 下限 = 0.0 上限 = 4.03896783473e-28 解 = 2.01948391737e-28
# 下限 = 0.0 上限 = 2.01948391737e-28 解 = 1.00974195868e-28
# 下限 = 0.0 上限 = 1.00974195868e-28 解 = 5.04870979341e-29
# 下限 = 0.0 上限 = 5.04870979341e-29 解 = 2.52435489671e-29
# 下限 = 0.0 上限 = 2.52435489671e-29 解 = 1.26217744835e-29
# 下限 = 0.0 上限 = 1.26217744835e-29 解 = 6.31088724177e-30
# 下限 = 0.0 上限 = 6.31088724177e-30 解 = 3.15544362088e-30
# 下限 = 0.0 上限 = 3.15544362088e-30 解 = 1.57772181044e-30
# 下限 = 0.0 上限 = 1.57772181044e-30 解 = 7.88860905221e-31
# 下限 = 0.0 上限 = 7.88860905221e-31 解 = 3.94430452611e-31
# 下限 = 0.0 上限 = 3.94430452611e-31 解 = 1.97215226305e-31
# 下限 = 0.0 上限 = 1.97215226305e-31 解 = 9.86076131526e-32
# 下限 = 0.0 上限 = 9.86076131526e-32 解 = 4.93038065763e-32
# 下限 = 0.0 上限 = 4.93038065763e-32 解 = 2.46519032882e-32
# 下限 = 0.0 上限 = 2.46519032882e-32 解 = 1.23259516441e-32
# 下限 = 0.0 上限 = 1.23259516441e-32 解 = 6.16297582204e-33
# 下限 = 0.0 上限 = 6.16297582204e-33 解 = 3.08148791102e-33
# 下限 = 0.0 上限 = 3.08148791102e-33 解 = 1.54074395551e-33
# 下限 = 0.0 上限 = 1.54074395551e-33 解 = 7.70371977755e-34
# 下限 = 0.0 上限 = 7.70371977755e-34 解 = 3.85185988877e-34
# 下限 = 0.0 上限 = 3.85185988877e-34 解 = 1.92592994439e-34
# 下限 = 0.0 上限 = 1.92592994439e-34 解 = 9.62964972194e-35
# 下限 = 0.0 上限 = 9.62964972194e-35 解 = 4.81482486097e-35
# 下限 = 0.0 上限 = 4.81482486097e-35 解 = 2.40741243048e-35
# 下限 = 0.0 上限 = 2.40741243048e-35 解 = 1.20370621524e-35
# 下限 = 0.0 上限 = 1.20370621524e-35 解 = 6.01853107621e-36
# 下限 = 0.0 上限 = 6.01853107621e-36 解 = 3.00926553811e-36
# 下限 = 0.0 上限 = 3.00926553811e-36 解 = 1.50463276905e-36
# 下限 = 0.0 上限 = 1.50463276905e-36 解 = 7.52316384526e-37
# 下限 = 0.0 上限 = 7.52316384526e-37 解 = 3.76158192263e-37
# 下限 = 0.0 上限 = 3.76158192263e-37 解 = 1.88079096132e-37
# 下限 = 0.0 上限 = 1.88079096132e-37 解 = 9.40395480658e-38
# 下限 = 0.0 上限 = 9.40395480658e-38 解 = 4.70197740329e-38
# 下限 = 0.0 上限 = 4.70197740329e-38 解 = 2.35098870164e-38
# 下限 = 0.0 上限 = 2.35098870164e-38 解 = 1.17549435082e-38
# 下限 = 0.0 上限 = 1.17549435082e-38 解 = 5.87747175411e-39
# 下限 = 0.0 上限 = 5.87747175411e-39 解 = 2.93873587706e-39
# 下限 = 0.0 上限 = 2.93873587706e-39 解 = 1.46936793853e-39
# 下限 = 0.0 上限 = 1.46936793853e-39 解 = 7.34683969264e-40
# 下限 = 0.0 上限 = 7.34683969264e-40 解 = 3.67341984632e-40
# 下限 = 0.0 上限 = 3.67341984632e-40 解 = 1.83670992316e-40
# 下限 = 0.0 上限 = 1.83670992316e-40 解 = 9.1835496158e-41
# 下限 = 0.0 上限 = 9.1835496158e-41 解 = 4.5917748079e-41
# 下限 = 0.0 上限 = 4.5917748079e-41 解 = 2.29588740395e-41
# 下限 = 0.0 上限 = 2.29588740395e-41 解 = 1.14794370197e-41
# 下限 = 0.0 上限 = 1.14794370197e-41 解 = 5.73971850987e-42
# 下限 = 0.0 上限 = 5.73971850987e-42 解 = 2.86985925494e-42
# 下限 = 0.0 上限 = 2.86985925494e-42 解 = 1.43492962747e-42
# 下限 = 0.0 上限 = 1.43492962747e-42 解 = 7.17464813734e-43
# 下限 = 0.0 上限 = 7.17464813734e-43 解 = 3.58732406867e-43
# 下限 = 0.0 上限 = 3.58732406867e-43 解 = 1.79366203434e-43
# 下限 = 0.0 上限 = 1.79366203434e-43 解 = 8.96831017168e-44
# 下限 = 0.0 上限 = 8.96831017168e-44 解 = 4.48415508584e-44
# 下限 = 0.0 上限 = 4.48415508584e-44 解 = 2.24207754292e-44
# 下限 = 0.0 上限 = 2.24207754292e-44 解 = 1.12103877146e-44
# 下限 = 0.0 上限 = 1.12103877146e-44 解 = 5.6051938573e-45
# 下限 = 0.0 上限 = 5.6051938573e-45 解 = 2.80259692865e-45
# 下限 = 0.0 上限 = 2.80259692865e-45 解 = 1.40129846432e-45
# 下限 = 0.0 上限 = 1.40129846432e-45 解 = 7.00649232162e-46
# 下限 = 0.0 上限 = 7.00649232162e-46 解 = 3.50324616081e-46
# 下限 = 0.0 上限 = 3.50324616081e-46 解 = 1.75162308041e-46
# 下限 = 0.0 上限 = 1.75162308041e-46 解 = 8.75811540203e-47
# 下限 = 0.0 上限 = 8.75811540203e-47 解 = 4.37905770102e-47
# 下限 = 0.0 上限 = 4.37905770102e-47 解 = 2.18952885051e-47
# 下限 = 0.0 上限 = 2.18952885051e-47 解 = 1.09476442525e-47
# 下限 = 0.0 上限 = 1.09476442525e-47 解 = 5.47382212627e-48
# 下限 = 0.0 上限 = 5.47382212627e-48 解 = 2.73691106313e-48
# 下限 = 0.0 上限 = 2.73691106313e-48 解 = 1.36845553157e-48
# 下限 = 0.0 上限 = 1.36845553157e-48 解 = 6.84227765784e-49
# 下限 = 0.0 上限 = 6.84227765784e-49 解 = 3.42113882892e-49
# 下限 = 0.0 上限 = 3.42113882892e-49 解 = 1.71056941446e-49
# 下限 = 0.0 上限 = 1.71056941446e-49 解 = 8.5528470723e-50
# 下限 = 0.0 上限 = 8.5528470723e-50 解 = 4.27642353615e-50
# 下限 = 0.0 上限 = 4.27642353615e-50 解 = 2.13821176807e-50
# 下限 = 0.0 上限 = 2.13821176807e-50 解 = 1.06910588404e-50
# 下限 = 0.0 上限 = 1.06910588404e-50 解 = 5.34552942018e-51
# 下限 = 0.0 上限 = 5.34552942018e-51 解 = 2.67276471009e-51
# 下限 = 0.0 上限 = 2.67276471009e-51 解 = 1.33638235505e-51
# 下限 = 0.0 上限 = 1.33638235505e-51 解 = 6.68191177523e-52
# 下限 = 0.0 上限 = 6.68191177523e-52 解 = 3.34095588762e-52
# 下限 = 0.0 上限 = 3.34095588762e-52 解 = 1.67047794381e-52
# 下限 = 0.0 上限 = 1.67047794381e-52 解 = 8.35238971904e-53
# 下限 = 0.0 上限 = 8.35238971904e-53 解 = 4.17619485952e-53
# 下限 = 0.0 上限 = 4.17619485952e-53 解 = 2.08809742976e-53
# 下限 = 0.0 上限 = 2.08809742976e-53 解 = 1.04404871488e-53
# 下限 = 0.0 上限 = 1.04404871488e-53 解 = 5.2202435744e-54
# 下限 = 0.0 上限 = 5.2202435744e-54 解 = 2.6101217872e-54
# 下限 = 0.0 上限 = 2.6101217872e-54 解 = 1.3050608936e-54
# 下限 = 0.0 上限 = 1.3050608936e-54 解 = 6.525304468e-55
# 下限 = 0.0 上限 = 6.525304468e-55 解 = 3.262652234e-55
# 下限 = 0.0 上限 = 3.262652234e-55 解 = 1.631326117e-55
# 下限 = 0.0 上限 = 1.631326117e-55 解 = 8.156630585e-56
# 下限 = 0.0 上限 = 8.156630585e-56 解 = 4.0783152925e-56
# 下限 = 0.0 上限 = 4.0783152925e-56 解 = 2.03915764625e-56
# 下限 = 0.0 上限 = 2.03915764625e-56 解 = 1.01957882312e-56
# 下限 = 0.0 上限 = 1.01957882312e-56 解 = 5.09789411562e-57
# 下限 = 0.0 上限 = 5.09789411562e-57 解 = 2.54894705781e-57
# 下限 = 0.0 上限 = 2.54894705781e-57 解 = 1.27447352891e-57
# 下限 = 0.0 上限 = 1.27447352891e-57 解 = 6.37236764453e-58
# 下限 = 0.0 上限 = 6.37236764453e-58 解 = 3.18618382226e-58
# 下限 = 0.0 上限 = 3.18618382226e-58 解 = 1.59309191113e-58
# 下限 = 0.0 上限 = 1.59309191113e-58 解 = 7.96545955566e-59
# 下限 = 0.0 上限 = 7.96545955566e-59 解 = 3.98272977783e-59
# 下限 = 0.0 上限 = 3.98272977783e-59 解 = 1.99136488892e-59
# 下限 = 0.0 上限 = 1.99136488892e-59 解 = 9.95682444458e-60
# 下限 = 0.0 上限 = 9.95682444458e-60 解 = 4.97841222229e-60
# 下限 = 0.0 上限 = 4.97841222229e-60 解 = 2.48920611114e-60
# 下限 = 0.0 上限 = 2.48920611114e-60 解 = 1.24460305557e-60
# 下限 = 0.0 上限 = 1.24460305557e-60 解 = 6.22301527786e-61
# 下限 = 0.0 上限 = 6.22301527786e-61 解 = 3.11150763893e-61
# 下限 = 0.0 上限 = 3.11150763893e-61 解 = 1.55575381947e-61
# 下限 = 0.0 上限 = 1.55575381947e-61 解 = 7.77876909733e-62
# 下限 = 0.0 上限 = 7.77876909733e-62 解 = 3.88938454866e-62
# 下限 = 0.0 上限 = 3.88938454866e-62 解 = 1.94469227433e-62
# 下限 = 0.0 上限 = 1.94469227433e-62 解 = 9.72346137166e-63
# 下限 = 0.0 上限 = 9.72346137166e-63 解 = 4.86173068583e-63
# 下限 = 0.0 上限 = 4.86173068583e-63 解 = 2.43086534291e-63
# 下限 = 0.0 上限 = 2.43086534291e-63 解 = 1.21543267146e-63
# 下限 = 0.0 上限 = 1.21543267146e-63 解 = 6.07716335729e-64
# 下限 = 0.0 上限 = 6.07716335729e-64 解 = 3.03858167864e-64
# 下限 = 0.0 上限 = 3.03858167864e-64 解 = 1.51929083932e-64
# 下限 = 0.0 上限 = 1.51929083932e-64 解 = 7.59645419661e-65
# 下限 = 0.0 上限 = 7.59645419661e-65 解 = 3.7982270983e-65
# 下限 = 0.0 上限 = 3.7982270983e-65 解 = 1.89911354915e-65
# 下限 = 0.0 上限 = 1.89911354915e-65 解 = 9.49556774576e-66
# 下限 = 0.0 上限 = 9.49556774576e-66 解 = 4.74778387288e-66
# 下限 = 0.0 上限 = 4.74778387288e-66 解 = 2.37389193644e-66
# 下限 = 0.0 上限 = 2.37389193644e-66 解 = 1.18694596822e-66
# 下限 = 0.0 上限 = 1.18694596822e-66 解 = 5.9347298411e-67
# 下限 = 0.0 上限 = 5.9347298411e-67 解 = 2.96736492055e-67
# 下限 = 0.0 上限 = 2.96736492055e-67 解 = 1.48368246027e-67
# 下限 = 0.0 上限 = 1.48368246027e-67 解 = 7.41841230137e-68
# 下限 = 0.0 上限 = 7.41841230137e-68 解 = 3.70920615069e-68
# 下限 = 0.0 上限 = 3.70920615069e-68 解 = 1.85460307534e-68
# 下限 = 0.0 上限 = 1.85460307534e-68 解 = 9.27301537672e-69
# 下限 = 0.0 上限 = 9.27301537672e-69 解 = 4.63650768836e-69
# 下限 = 0.0 上限 = 4.63650768836e-69 解 = 2.31825384418e-69
# 下限 = 0.0 上限 = 2.31825384418e-69 解 = 1.15912692209e-69
# 下限 = 0.0 上限 = 1.15912692209e-69 解 = 5.79563461045e-70
# 下限 = 0.0 上限 = 5.79563461045e-70 解 = 2.89781730522e-70
# 下限 = 0.0 上限 = 2.89781730522e-70 解 = 1.44890865261e-70
# 下限 = 0.0 上限 = 1.44890865261e-70 解 = 7.24454326306e-71
# 下限 = 0.0 上限 = 7.24454326306e-71 解 = 3.62227163153e-71
# 下限 = 0.0 上限 = 3.62227163153e-71 解 = 1.81113581577e-71
# 下限 = 0.0 上限 = 1.81113581577e-71 解 = 9.05567907883e-72
# 下限 = 0.0 上限 = 9.05567907883e-72 解 = 4.52783953941e-72
# 下限 = 0.0 上限 = 4.52783953941e-72 解 = 2.26391976971e-72
# 下限 = 0.0 上限 = 2.26391976971e-72 解 = 1.13195988485e-72
# 下限 = 0.0 上限 = 1.13195988485e-72 解 = 5.65979942427e-73
# 下限 = 0.0 上限 = 5.65979942427e-73 解 = 2.82989971213e-73
# 下限 = 0.0 上限 = 2.82989971213e-73 解 = 1.41494985607e-73
# 下限 = 0.0 上限 = 1.41494985607e-73 解 = 7.07474928033e-74
# 下限 = 0.0 上限 = 7.07474928033e-74 解 = 3.53737464017e-74
# 下限 = 0.0 上限 = 3.53737464017e-74 解 = 1.76868732008e-74
# 下限 = 0.0 上限 = 1.76868732008e-74 解 = 8.84343660042e-75
# 下限 = 0.0 上限 = 8.84343660042e-75 解 = 4.42171830021e-75
# 下限 = 0.0 上限 = 4.42171830021e-75 解 = 2.2108591501e-75
# 下限 = 0.0 上限 = 2.2108591501e-75 解 = 1.10542957505e-75
# 下限 = 0.0 上限 = 1.10542957505e-75 解 = 5.52714787526e-76
# 下限 = 0.0 上限 = 5.52714787526e-76 解 = 2.76357393763e-76
# 下限 = 0.0 上限 = 2.76357393763e-76 解 = 1.38178696882e-76
# 下限 = 0.0 上限 = 1.38178696882e-76 解 = 6.90893484408e-77
# 下限 = 0.0 上限 = 6.90893484408e-77 解 = 3.45446742204e-77
# 下限 = 0.0 上限 = 3.45446742204e-77 解 = 1.72723371102e-77
# 下限 = 0.0 上限 = 1.72723371102e-77 解 = 8.63616855509e-78
# 下限 = 0.0 上限 = 8.63616855509e-78 解 = 4.31808427755e-78
# 下限 = 0.0 上限 = 4.31808427755e-78 解 = 2.15904213877e-78
# 下限 = 0.0 上限 = 2.15904213877e-78 解 = 1.07952106939e-78
# 下限 = 0.0 上限 = 1.07952106939e-78 解 = 5.39760534693e-79
# 下限 = 0.0 上限 = 5.39760534693e-79 解 = 2.69880267347e-79
# 下限 = 0.0 上限 = 2.69880267347e-79 解 = 1.34940133673e-79
# 下限 = 0.0 上限 = 1.34940133673e-79 解 = 6.74700668367e-80
# 下限 = 0.0 上限 = 6.74700668367e-80 解 = 3.37350334183e-80
# 下限 = 0.0 上限 = 3.37350334183e-80 解 = 1.68675167092e-80
# 下限 = 0.0 上限 = 1.68675167092e-80 解 = 8.43375835458e-81
# 下限 = 0.0 上限 = 8.43375835458e-81 解 = 4.21687917729e-81
# 下限 = 0.0 上限 = 4.21687917729e-81 解 = 2.10843958865e-81
# 下限 = 0.0 上限 = 2.10843958865e-81 解 = 1.05421979432e-81
# 下限 = 0.0 上限 = 1.05421979432e-81 解 = 5.27109897162e-82
# 下限 = 0.0 上限 = 5.27109897162e-82 解 = 2.63554948581e-82
# 下限 = 0.0 上限 = 2.63554948581e-82 解 = 1.3177747429e-82
# 下限 = 0.0 上限 = 1.3177747429e-82 解 = 6.58887371452e-83
# 下限 = 0.0 上限 = 6.58887371452e-83 解 = 3.29443685726e-83
# 下限 = 0.0 上限 = 3.29443685726e-83 解 = 1.64721842863e-83
# 下限 = 0.0 上限 = 1.64721842863e-83 解 = 8.23609214315e-84
# 下限 = 0.0 上限 = 8.23609214315e-84 解 = 4.11804607157e-84
# 下限 = 0.0 上限 = 4.11804607157e-84 解 = 2.05902303579e-84
# 下限 = 0.0 上限 = 2.05902303579e-84 解 = 1.02951151789e-84
# 下限 = 0.0 上限 = 1.02951151789e-84 解 = 5.14755758947e-85
# 下限 = 0.0 上限 = 5.14755758947e-85 解 = 2.57377879473e-85
# 下限 = 0.0 上限 = 2.57377879473e-85 解 = 1.28688939737e-85
# 下限 = 0.0 上限 = 1.28688939737e-85 解 = 6.43444698684e-86
# 下限 = 0.0 上限 = 6.43444698684e-86 解 = 3.21722349342e-86
# 下限 = 0.0 上限 = 3.21722349342e-86 解 = 1.60861174671e-86
# 下限 = 0.0 上限 = 1.60861174671e-86 解 = 8.04305873354e-87
# 下限 = 0.0 上限 = 8.04305873354e-87 解 = 4.02152936677e-87
# 下限 = 0.0 上限 = 4.02152936677e-87 解 = 2.01076468339e-87
# 下限 = 0.0 上限 = 2.01076468339e-87 解 = 1.00538234169e-87
# 下限 = 0.0 上限 = 1.00538234169e-87 解 = 5.02691170846e-88
# 下限 = 0.0 上限 = 5.02691170846e-88 解 = 2.51345585423e-88
# 下限 = 0.0 上限 = 2.51345585423e-88 解 = 1.25672792712e-88
# 下限 = 0.0 上限 = 1.25672792712e-88 解 = 6.28363963558e-89
# 下限 = 0.0 上限 = 6.28363963558e-89 解 = 3.14181981779e-89
# 下限 = 0.0 上限 = 3.14181981779e-89 解 = 1.5709099089e-89
# 下限 = 0.0 上限 = 1.5709099089e-89 解 = 7.85454954448e-90
# 下限 = 0.0 上限 = 7.85454954448e-90 解 = 3.92727477224e-90
# 下限 = 0.0 上限 = 3.92727477224e-90 解 = 1.96363738612e-90
# 下限 = 0.0 上限 = 1.96363738612e-90 解 = 9.8181869306e-91
# 下限 = 0.0 上限 = 9.8181869306e-91 解 = 4.9090934653e-91
# 下限 = 0.0 上限 = 4.9090934653e-91 解 = 2.45454673265e-91
# 下限 = 0.0 上限 = 2.45454673265e-91 解 = 1.22727336632e-91
# 下限 = 0.0 上限 = 1.22727336632e-91 解 = 6.13636683162e-92
# 下限 = 0.0 上限 = 6.13636683162e-92 解 = 3.06818341581e-92
# 下限 = 0.0 上限 = 3.06818341581e-92 解 = 1.53409170791e-92
# 下限 = 0.0 上限 = 1.53409170791e-92 解 = 7.67045853953e-93
# 下限 = 0.0 上限 = 7.67045853953e-93 解 = 3.83522926976e-93
# 下限 = 0.0 上限 = 3.83522926976e-93 解 = 1.91761463488e-93
# 下限 = 0.0 上限 = 1.91761463488e-93 解 = 9.58807317441e-94
# 下限 = 0.0 上限 = 9.58807317441e-94 解 = 4.7940365872e-94
# 下限 = 0.0 上限 = 4.7940365872e-94 解 = 2.3970182936e-94
# 下限 = 0.0 上限 = 2.3970182936e-94 解 = 1.1985091468e-94
# 下限 = 0.0 上限 = 1.1985091468e-94 解 = 5.99254573401e-95
# 下限 = 0.0 上限 = 5.99254573401e-95 解 = 2.996272867e-95
# 下限 = 0.0 上限 = 2.996272867e-95 解 = 1.4981364335e-95
# 下限 = 0.0 上限 = 1.4981364335e-95 解 = 7.49068216751e-96
# 下限 = 0.0 上限 = 7.49068216751e-96 解 = 3.74534108375e-96
# 下限 = 0.0 上限 = 3.74534108375e-96 解 = 1.87267054188e-96
# 下限 = 0.0 上限 = 1.87267054188e-96 解 = 9.36335270938e-97
# 下限 = 0.0 上限 = 9.36335270938e-97 解 = 4.68167635469e-97
# 下限 = 0.0 上限 = 4.68167635469e-97 解 = 2.34083817735e-97
# 下限 = 0.0 上限 = 2.34083817735e-97 解 = 1.17041908867e-97
# 下限 = 0.0 上限 = 1.17041908867e-97 解 = 5.85209544337e-98
# 下限 = 0.0 上限 = 5.85209544337e-98 解 = 2.92604772168e-98
# 下限 = 0.0 上限 = 2.92604772168e-98 解 = 1.46302386084e-98
# 下限 = 0.0 上限 = 1.46302386084e-98 解 = 7.31511930421e-99
# 下限 = 0.0 上限 = 7.31511930421e-99 解 = 3.6575596521e-99
# 下限 = 0.0 上限 = 3.6575596521e-99 解 = 1.82877982605e-99
# 下限 = 0.0 上限 = 1.82877982605e-99 解 = 9.14389913026e-100
# 下限 = 0.0 上限 = 9.14389913026e-100 解 = 4.57194956513e-100
# 下限 = 0.0 上限 = 4.57194956513e-100 解 = 2.28597478256e-100
# 下限 = 0.0 上限 = 2.28597478256e-100 解 = 1.14298739128e-100
# 下限 = 0.0 上限 = 1.14298739128e-100 解 = 5.71493695641e-101
# 下限 = 0.0 上限 = 5.71493695641e-101 解 = 2.85746847821e-101
# 下限 = 0.0 上限 = 2.85746847821e-101 解 = 1.4287342391e-101
# 下限 = 0.0 上限 = 1.4287342391e-101 解 = 7.14367119551e-102
# 下限 = 0.0 上限 = 7.14367119551e-102 解 = 3.57183559776e-102
# 下限 = 0.0 上限 = 3.57183559776e-102 解 = 1.78591779888e-102
# 下限 = 0.0 上限 = 1.78591779888e-102 解 = 8.92958899439e-103
# 下限 = 0.0 上限 = 8.92958899439e-103 解 = 4.4647944972e-103
# 下限 = 0.0 上限 = 4.4647944972e-103 解 = 2.2323972486e-103
# 下限 = 0.0 上限 = 2.2323972486e-103 解 = 1.1161986243e-103
# 下限 = 0.0 上限 = 1.1161986243e-103 解 = 5.5809931215e-104
# 下限 = 0.0 上限 = 5.5809931215e-104 解 = 2.79049656075e-104
# 下限 = 0.0 上限 = 2.79049656075e-104 解 = 1.39524828037e-104
# 下限 = 0.0 上限 = 1.39524828037e-104 解 = 6.97624140187e-105
# 下限 = 0.0 上限 = 6.97624140187e-105 解 = 3.48812070093e-105
# 下限 = 0.0 上限 = 3.48812070093e-105 解 = 1.74406035047e-105
# 下限 = 0.0 上限 = 1.74406035047e-105 解 = 8.72030175234e-106
# 下限 = 0.0 上限 = 8.72030175234e-106 解 = 4.36015087617e-106
# 下限 = 0.0 上限 = 4.36015087617e-106 解 = 2.18007543808e-106
# 下限 = 0.0 上限 = 2.18007543808e-106 解 = 1.09003771904e-106
# 下限 = 0.0 上限 = 1.09003771904e-106 解 = 5.45018859521e-107
# 下限 = 0.0 上限 = 5.45018859521e-107 解 = 2.72509429761e-107
# 下限 = 0.0 上限 = 2.72509429761e-107 解 = 1.3625471488e-107
# 下限 = 0.0 上限 = 1.3625471488e-107 解 = 6.81273574401e-108
# 下限 = 0.0 上限 = 6.81273574401e-108 解 = 3.40636787201e-108
# 下限 = 0.0 上限 = 3.40636787201e-108 解 = 1.703183936e-108
# 下限 = 0.0 上限 = 1.703183936e-108 解 = 8.51591968002e-109
# 下限 = 0.0 上限 = 8.51591968002e-109 解 = 4.25795984001e-109
# 下限 = 0.0 上限 = 4.25795984001e-109 解 = 2.12897992e-109
# 下限 = 0.0 上限 = 2.12897992e-109 解 = 1.06448996e-109
# 下限 = 0.0 上限 = 1.06448996e-109 解 = 5.32244980001e-110
# 下限 = 0.0 上限 = 5.32244980001e-110 解 = 2.66122490001e-110
# 下限 = 0.0 上限 = 2.66122490001e-110 解 = 1.33061245e-110
# 下限 = 0.0 上限 = 1.33061245e-110 解 = 6.65306225001e-111
# 下限 = 0.0 上限 = 6.65306225001e-111 解 = 3.32653112501e-111
# 下限 = 0.0 上限 = 3.32653112501e-111 解 = 1.6632655625e-111
# 下限 = 0.0 上限 = 1.6632655625e-111 解 = 8.31632781252e-112
# 下限 = 0.0 上限 = 8.31632781252e-112 解 = 4.15816390626e-112
# 下限 = 0.0 上限 = 4.15816390626e-112 解 = 2.07908195313e-112
# 下限 = 0.0 上限 = 2.07908195313e-112 解 = 1.03954097656e-112
# 下限 = 0.0 上限 = 1.03954097656e-112 解 = 5.19770488282e-113
# 下限 = 0.0 上限 = 5.19770488282e-113 解 = 2.59885244141e-113
# 下限 = 0.0 上限 = 2.59885244141e-113 解 = 1.29942622071e-113
# 下限 = 0.0 上限 = 1.29942622071e-113 解 = 6.49713110353e-114
# 下限 = 0.0 上限 = 6.49713110353e-114 解 = 3.24856555176e-114
# 下限 = 0.0 上限 = 3.24856555176e-114 解 = 1.62428277588e-114
# 下限 = 0.0 上限 = 1.62428277588e-114 解 = 8.12141387941e-115
# 下限 = 0.0 上限 = 8.12141387941e-115 解 = 4.06070693971e-115
# 下限 = 0.0 上限 = 4.06070693971e-115 解 = 2.03035346985e-115
# 下限 = 0.0 上限 = 2.03035346985e-115 解 = 1.01517673493e-115
# 下限 = 0.0 上限 = 1.01517673493e-115 解 = 5.07588367463e-116
# 下限 = 0.0 上限 = 5.07588367463e-116 解 = 2.53794183732e-116
# 下限 = 0.0 上限 = 2.53794183732e-116 解 = 1.26897091866e-116
# 下限 = 0.0 上限 = 1.26897091866e-116 解 = 6.34485459329e-117
# 下限 = 0.0 上限 = 6.34485459329e-117 解 = 3.17242729664e-117
# 下限 = 0.0 上限 = 3.17242729664e-117 解 = 1.58621364832e-117
# 下限 = 0.0 上限 = 1.58621364832e-117 解 = 7.93106824161e-118
# 下限 = 0.0 上限 = 7.93106824161e-118 解 = 3.96553412081e-118
# 下限 = 0.0 上限 = 3.96553412081e-118 解 = 1.9827670604e-118
# 下限 = 0.0 上限 = 1.9827670604e-118 解 = 9.91383530201e-119
# 下限 = 0.0 上限 = 9.91383530201e-119 解 = 4.95691765101e-119
# 下限 = 0.0 上限 = 4.95691765101e-119 解 = 2.4784588255e-119
# 下限 = 0.0 上限 = 2.4784588255e-119 解 = 1.23922941275e-119
# 下限 = 0.0 上限 = 1.23922941275e-119 解 = 6.19614706376e-120
# 下限 = 0.0 上限 = 6.19614706376e-120 解 = 3.09807353188e-120
# 下限 = 0.0 上限 = 3.09807353188e-120 解 = 1.54903676594e-120
# 下限 = 0.0 上限 = 1.54903676594e-120 解 = 7.7451838297e-121
# 下限 = 0.0 上限 = 7.7451838297e-121 解 = 3.87259191485e-121
# 下限 = 0.0 上限 = 3.87259191485e-121 解 = 1.93629595742e-121
# 下限 = 0.0 上限 = 1.93629595742e-121 解 = 9.68147978712e-122
# 下限 = 0.0 上限 = 9.68147978712e-122 解 = 4.84073989356e-122
# 下限 = 0.0 上限 = 4.84073989356e-122 解 = 2.42036994678e-122
# 下限 = 0.0 上限 = 2.42036994678e-122 解 = 1.21018497339e-122
# 下限 = 0.0 上限 = 1.21018497339e-122 解 = 6.05092486695e-123
# 下限 = 0.0 上限 = 6.05092486695e-123 解 = 3.02546243348e-123
# 下限 = 0.0 上限 = 3.02546243348e-123 解 = 1.51273121674e-123
# 下限 = 0.0 上限 = 1.51273121674e-123 解 = 7.56365608369e-124
# 下限 = 0.0 上限 = 7.56365608369e-124 解 = 3.78182804185e-124
# 下限 = 0.0 上限 = 3.78182804185e-124 解 = 1.89091402092e-124
# 下限 = 0.0 上限 = 1.89091402092e-124 解 = 9.45457010461e-125
# 下限 = 0.0 上限 = 9.45457010461e-125 解 = 4.72728505231e-125
# 下限 = 0.0 上限 = 4.72728505231e-125 解 = 2.36364252615e-125
# 下限 = 0.0 上限 = 2.36364252615e-125 解 = 1.18182126308e-125
# 下限 = 0.0 上限 = 1.18182126308e-125 解 = 5.90910631538e-126
# 下限 = 0.0 上限 = 5.90910631538e-126 解 = 2.95455315769e-126
# 下限 = 0.0 上限 = 2.95455315769e-126 解 = 1.47727657885e-126
# 下限 = 0.0 上限 = 1.47727657885e-126 解 = 7.38638289423e-127
# 下限 = 0.0 上限 = 7.38638289423e-127 解 = 3.69319144711e-127
# 下限 = 0.0 上限 = 3.69319144711e-127 解 = 1.84659572356e-127
# 下限 = 0.0 上限 = 1.84659572356e-127 解 = 9.23297861779e-128
# 下限 = 0.0 上限 = 9.23297861779e-128 解 = 4.61648930889e-128
# 下限 = 0.0 上限 = 4.61648930889e-128 解 = 2.30824465445e-128
# 下限 = 0.0 上限 = 2.30824465445e-128 解 = 1.15412232722e-128
# 下限 = 0.0 上限 = 1.15412232722e-128 解 = 5.77061163612e-129
# 下限 = 0.0 上限 = 5.77061163612e-129 解 = 2.88530581806e-129
# 下限 = 0.0 上限 = 2.88530581806e-129 解 = 1.44265290903e-129
# 下限 = 0.0 上限 = 1.44265290903e-129 解 = 7.21326454515e-130
# 下限 = 0.0 上限 = 7.21326454515e-130 解 = 3.60663227257e-130
# 下限 = 0.0 上限 = 3.60663227257e-130 解 = 1.80331613629e-130
# 下限 = 0.0 上限 = 1.80331613629e-130 解 = 9.01658068143e-131
# 下限 = 0.0 上限 = 9.01658068143e-131 解 = 4.50829034072e-131
# 下限 = 0.0 上限 = 4.50829034072e-131 解 = 2.25414517036e-131
# 下限 = 0.0 上限 = 2.25414517036e-131 解 = 1.12707258518e-131
# 下限 = 0.0 上限 = 1.12707258518e-131 解 = 5.63536292589e-132
# 下限 = 0.0 上限 = 5.63536292589e-132 解 = 2.81768146295e-132
# 下限 = 0.0 上限 = 2.81768146295e-132 解 = 1.40884073147e-132
# 下限 = 0.0 上限 = 1.40884073147e-132 解 = 7.04420365737e-133
# 下限 = 0.0 上限 = 7.04420365737e-133 解 = 3.52210182868e-133
# 下限 = 0.0 上限 = 3.52210182868e-133 解 = 1.76105091434e-133
# 下限 = 0.0 上限 = 1.76105091434e-133 解 = 8.80525457171e-134
# 下限 = 0.0 上限 = 8.80525457171e-134 解 = 4.40262728586e-134
# 下限 = 0.0 上限 = 4.40262728586e-134 解 = 2.20131364293e-134
# 下限 = 0.0 上限 = 2.20131364293e-134 解 = 1.10065682146e-134
# 下限 = 0.0 上限 = 1.10065682146e-134 解 = 5.50328410732e-135
# 下限 = 0.0 上限 = 5.50328410732e-135 解 = 2.75164205366e-135
# 下限 = 0.0 上限 = 2.75164205366e-135 解 = 1.37582102683e-135
# 下限 = 0.0 上限 = 1.37582102683e-135 解 = 6.87910513415e-136
# 下限 = 0.0 上限 = 6.87910513415e-136 解 = 3.43955256707e-136
# 下限 = 0.0 上限 = 3.43955256707e-136 解 = 1.71977628354e-136
# 下限 = 0.0 上限 = 1.71977628354e-136 解 = 8.59888141769e-137
# 下限 = 0.0 上限 = 8.59888141769e-137 解 = 4.29944070884e-137
# 下限 = 0.0 上限 = 4.29944070884e-137 解 = 2.14972035442e-137
# 下限 = 0.0 上限 = 2.14972035442e-137 解 = 1.07486017721e-137
# 下限 = 0.0 上限 = 1.07486017721e-137 解 = 5.37430088605e-138
# 下限 = 0.0 上限 = 5.37430088605e-138 解 = 2.68715044303e-138
# 下限 = 0.0 上限 = 2.68715044303e-138 解 = 1.34357522151e-138
# 下限 = 0.0 上限 = 1.34357522151e-138 解 = 6.71787610757e-139
# 下限 = 0.0 上限 = 6.71787610757e-139 解 = 3.35893805378e-139
# 下限 = 0.0 上限 = 3.35893805378e-139 解 = 1.67946902689e-139
# 下限 = 0.0 上限 = 1.67946902689e-139 解 = 8.39734513446e-140
# 下限 = 0.0 上限 = 8.39734513446e-140 解 = 4.19867256723e-140
# 下限 = 0.0 上限 = 4.19867256723e-140 解 = 2.09933628361e-140
# 下限 = 0.0 上限 = 2.09933628361e-140 解 = 1.04966814181e-140
# 下限 = 0.0 上限 = 1.04966814181e-140 解 = 5.24834070904e-141
# 下限 = 0.0 上限 = 5.24834070904e-141 解 = 2.62417035452e-141
# 下限 = 0.0 上限 = 2.62417035452e-141 解 = 1.31208517726e-141
# 下限 = 0.0 上限 = 1.31208517726e-141 解 = 6.5604258863e-142
# 下限 = 0.0 上限 = 6.5604258863e-142 解 = 3.28021294315e-142
# 下限 = 0.0 上限 = 3.28021294315e-142 解 = 1.64010647157e-142
# 下限 = 0.0 上限 = 1.64010647157e-142 解 = 8.20053235787e-143
# 下限 = 0.0 上限 = 8.20053235787e-143 解 = 4.10026617893e-143
# 下限 = 0.0 上限 = 4.10026617893e-143 解 = 2.05013308947e-143
# 下限 = 0.0 上限 = 2.05013308947e-143 解 = 1.02506654473e-143
# 下限 = 0.0 上限 = 1.02506654473e-143 解 = 5.12533272367e-144
# 下限 = 0.0 上限 = 5.12533272367e-144 解 = 2.56266636183e-144
# 下限 = 0.0 上限 = 2.56266636183e-144 解 = 1.28133318092e-144
# 下限 = 0.0 上限 = 1.28133318092e-144 解 = 6.40666590459e-145
# 下限 = 0.0 上限 = 6.40666590459e-145 解 = 3.20333295229e-145
# 下限 = 0.0 上限 = 3.20333295229e-145 解 = 1.60166647615e-145
# 下限 = 0.0 上限 = 1.60166647615e-145 解 = 8.00833238073e-146
# 下限 = 0.0 上限 = 8.00833238073e-146 解 = 4.00416619037e-146
# 下限 = 0.0 上限 = 4.00416619037e-146 解 = 2.00208309518e-146
# 下限 = 0.0 上限 = 2.00208309518e-146 解 = 1.00104154759e-146
# 下限 = 0.0 上限 = 1.00104154759e-146 解 = 5.00520773796e-147
# 下限 = 0.0 上限 = 5.00520773796e-147 解 = 2.50260386898e-147
# 下限 = 0.0 上限 = 2.50260386898e-147 解 = 1.25130193449e-147
# 下限 = 0.0 上限 = 1.25130193449e-147 解 = 6.25650967245e-148
# 下限 = 0.0 上限 = 6.25650967245e-148 解 = 3.12825483622e-148
# 下限 = 0.0 上限 = 3.12825483622e-148 解 = 1.56412741811e-148
# 下限 = 0.0 上限 = 1.56412741811e-148 解 = 7.82063709056e-149
# 下限 = 0.0 上限 = 7.82063709056e-149 解 = 3.91031854528e-149
# 下限 = 0.0 上限 = 3.91031854528e-149 解 = 1.95515927264e-149
# 下限 = 0.0 上限 = 1.95515927264e-149 解 = 9.7757963632e-150
# 下限 = 0.0 上限 = 9.7757963632e-150 解 = 4.8878981816e-150
# 下限 = 0.0 上限 = 4.8878981816e-150 解 = 2.4439490908e-150
# 下限 = 0.0 上限 = 2.4439490908e-150 解 = 1.2219745454e-150
# 下限 = 0.0 上限 = 1.2219745454e-150 解 = 6.109872727e-151
# 下限 = 0.0 上限 = 6.109872727e-151 解 = 3.0549363635e-151
# 下限 = 0.0 上限 = 3.0549363635e-151 解 = 1.52746818175e-151
# 下限 = 0.0 上限 = 1.52746818175e-151 解 = 7.63734090875e-152
# 下限 = 0.0 上限 = 7.63734090875e-152 解 = 3.81867045437e-152
# 下限 = 0.0 上限 = 3.81867045437e-152 解 = 1.90933522719e-152
# 下限 = 0.0 上限 = 1.90933522719e-152 解 = 9.54667613594e-153
# 下限 = 0.0 上限 = 9.54667613594e-153 解 = 4.77333806797e-153
# 下限 = 0.0 上限 = 4.77333806797e-153 解 = 2.38666903398e-153
# 下限 = 0.0 上限 = 2.38666903398e-153 解 = 1.19333451699e-153
# 下限 = 0.0 上限 = 1.19333451699e-153 解 = 5.96667258496e-154
# 下限 = 0.0 上限 = 5.96667258496e-154 解 = 2.98333629248e-154
# 下限 = 0.0 上限 = 2.98333629248e-154 解 = 1.49166814624e-154
# 下限 = 0.0 上限 = 1.49166814624e-154 解 = 7.4583407312e-155
# 下限 = 0.0 上限 = 7.4583407312e-155 解 = 3.7291703656e-155
# 下限 = 0.0 上限 = 3.7291703656e-155 解 = 1.8645851828e-155
# 下限 = 0.0 上限 = 1.8645851828e-155 解 = 9.322925914e-156
# 下限 = 0.0 上限 = 9.322925914e-156 解 = 4.661462957e-156
# 下限 = 0.0 上限 = 4.661462957e-156 解 = 2.3307314785e-156
# 下限 = 0.0 上限 = 2.3307314785e-156 解 = 1.16536573925e-156
# 下限 = 0.0 上限 = 1.16536573925e-156 解 = 5.82682869625e-157
# 下限 = 0.0 上限 = 5.82682869625e-157 解 = 2.91341434813e-157
# 下限 = 0.0 上限 = 2.91341434813e-157 解 = 1.45670717406e-157
# 下限 = 0.0 上限 = 1.45670717406e-157 解 = 7.28353587031e-158
# 下限 = 0.0 上限 = 7.28353587031e-158 解 = 3.64176793516e-158
# 下限 = 0.0 上限 = 3.64176793516e-158 解 = 1.82088396758e-158
# 下限 = 0.0 上限 = 1.82088396758e-158 解 = 9.10441983789e-159
# 下限 = 0.0 上限 = 9.10441983789e-159 解 = 4.55220991895e-159
# 下限 = 0.0 上限 = 4.55220991895e-159 解 = 2.27610495947e-159
# 下限 = 0.0 上限 = 2.27610495947e-159 解 = 1.13805247974e-159
# 下限 = 0.0 上限 = 1.13805247974e-159 解 = 5.69026239868e-160
# 下限 = 0.0 上限 = 5.69026239868e-160 解 = 2.84513119934e-160
# 下限 = 0.0 上限 = 2.84513119934e-160 解 = 1.42256559967e-160
# 下限 = 0.0 上限 = 1.42256559967e-160 解 = 7.11282799835e-161
# 下限 = 0.0 上限 = 7.11282799835e-161 解 = 3.55641399918e-161
# 下限 = 0.0 上限 = 3.55641399918e-161 解 = 1.77820699959e-161
# 下限 = 0.0 上限 = 1.77820699959e-161 解 = 8.89103499794e-162
# 下限 = 0.0 上限 = 8.89103499794e-162 解 = 4.44551749897e-162
# 下限 = 0.0 上限 = 4.44551749897e-162 解 = 2.22275874949e-162
# 下限 = 0.0 上限 = 2.22275874949e-162 解 = 1.11137937474e-162
# 下限 = 0.0 上限 = 1.11137937474e-162 解 = 5.55689687371e-163
# 下限 = 0.0 上限 = 5.55689687371e-163 解 = 2.77844843686e-163
# 下限 = 0.0 上限 = 2.77844843686e-163 解 = 1.38922421843e-163
# 下限 = 0.0 上限 = 1.38922421843e-163 解 = 6.94612109214e-164
# 下限 = 0.0 上限 = 6.94612109214e-164 解 = 3.47306054607e-164
# 下限 = 0.0 上限 = 3.47306054607e-164 解 = 1.73653027304e-164
# 下限 = 0.0 上限 = 1.73653027304e-164 解 = 8.68265136518e-165
# 下限 = 0.0 上限 = 8.68265136518e-165 解 = 4.34132568259e-165
# 下限 = 0.0 上限 = 4.34132568259e-165 解 = 2.17066284129e-165
# 下限 = 0.0 上限 = 2.17066284129e-165 解 = 1.08533142065e-165
# 下限 = 0.0 上限 = 1.08533142065e-165 解 = 5.42665710324e-166
# 下限 = 0.0 上限 = 5.42665710324e-166 解 = 2.71332855162e-166
# 下限 = 0.0 上限 = 2.71332855162e-166 解 = 1.35666427581e-166
# 下限 = 0.0 上限 = 1.35666427581e-166 解 = 6.78332137904e-167
# 下限 = 0.0 上限 = 6.78332137904e-167 解 = 3.39166068952e-167
# 下限 = 0.0 上限 = 3.39166068952e-167 解 = 1.69583034476e-167
# 下限 = 0.0 上限 = 1.69583034476e-167 解 = 8.4791517238e-168
# 下限 = 0.0 上限 = 8.4791517238e-168 解 = 4.2395758619e-168
# 下限 = 0.0 上限 = 4.2395758619e-168 解 = 2.11978793095e-168
# 下限 = 0.0 上限 = 2.11978793095e-168 解 = 1.05989396548e-168
# 下限 = 0.0 上限 = 1.05989396548e-168 解 = 5.29946982738e-169
# 下限 = 0.0 上限 = 5.29946982738e-169 解 = 2.64973491369e-169
# 下限 = 0.0 上限 = 2.64973491369e-169 解 = 1.32486745684e-169
# 下限 = 0.0 上限 = 1.32486745684e-169 解 = 6.62433728422e-170
# 下限 = 0.0 上限 = 6.62433728422e-170 解 = 3.31216864211e-170
# 下限 = 0.0 上限 = 3.31216864211e-170 解 = 1.65608432106e-170
# 下限 = 0.0 上限 = 1.65608432106e-170 解 = 8.28042160528e-171
# 下限 = 0.0 上限 = 8.28042160528e-171 解 = 4.14021080264e-171
# 下限 = 0.0 上限 = 4.14021080264e-171 解 = 2.07010540132e-171
# 下限 = 0.0 上限 = 2.07010540132e-171 解 = 1.03505270066e-171
# 下限 = 0.0 上限 = 1.03505270066e-171 解 = 5.1752635033e-172
# 下限 = 0.0 上限 = 5.1752635033e-172 解 = 2.58763175165e-172
# 下限 = 0.0 上限 = 2.58763175165e-172 解 = 1.29381587582e-172
# 下限 = 0.0 上限 = 1.29381587582e-172 解 = 6.46907937912e-173
# 下限 = 0.0 上限 = 6.46907937912e-173 解 = 3.23453968956e-173
# 下限 = 0.0 上限 = 3.23453968956e-173 解 = 1.61726984478e-173
# 下限 = 0.0 上限 = 1.61726984478e-173 解 = 8.0863492239e-174
# 下限 = 0.0 上限 = 8.0863492239e-174 解 = 4.04317461195e-174
# 下限 = 0.0 上限 = 4.04317461195e-174 解 = 2.02158730598e-174
# 下限 = 0.0 上限 = 2.02158730598e-174 解 = 1.01079365299e-174
# 下限 = 0.0 上限 = 1.01079365299e-174 解 = 5.05396826494e-175
# 下限 = 0.0 上限 = 5.05396826494e-175 解 = 2.52698413247e-175
# 下限 = 0.0 上限 = 2.52698413247e-175 解 = 1.26349206624e-175
# 下限 = 0.0 上限 = 1.26349206624e-175 解 = 6.31746033118e-176
# 下限 = 0.0 上限 = 6.31746033118e-176 解 = 3.15873016559e-176
# 下限 = 0.0 上限 = 3.15873016559e-176 解 = 1.57936508279e-176
# 下限 = 0.0 上限 = 1.57936508279e-176 解 = 7.89682541397e-177
# 下限 = 0.0 上限 = 7.89682541397e-177 解 = 3.94841270698e-177
# 下限 = 0.0 上限 = 3.94841270698e-177 解 = 1.97420635349e-177
# 下限 = 0.0 上限 = 1.97420635349e-177 解 = 9.87103176746e-178
# 下限 = 0.0 上限 = 9.87103176746e-178 解 = 4.93551588373e-178
# 下限 = 0.0 上限 = 4.93551588373e-178 解 = 2.46775794187e-178
# 下限 = 0.0 上限 = 2.46775794187e-178 解 = 1.23387897093e-178
# 下限 = 0.0 上限 = 1.23387897093e-178 解 = 6.16939485466e-179
# 下限 = 0.0 上限 = 6.16939485466e-179 解 = 3.08469742733e-179
# 下限 = 0.0 上限 = 3.08469742733e-179 解 = 1.54234871367e-179
# 下限 = 0.0 上限 = 1.54234871367e-179 解 = 7.71174356833e-180
# 下限 = 0.0 上限 = 7.71174356833e-180 解 = 3.85587178416e-180
# 下限 = 0.0 上限 = 3.85587178416e-180 解 = 1.92793589208e-180
# 下限 = 0.0 上限 = 1.92793589208e-180 解 = 9.63967946041e-181
# 下限 = 0.0 上限 = 9.63967946041e-181 解 = 4.81983973021e-181
# 下限 = 0.0 上限 = 4.81983973021e-181 解 = 2.4099198651e-181
# 下限 = 0.0 上限 = 2.4099198651e-181 解 = 1.20495993255e-181
# 下限 = 0.0 上限 = 1.20495993255e-181 解 = 6.02479966276e-182
# 下限 = 0.0 上限 = 6.02479966276e-182 解 = 3.01239983138e-182
# 下限 = 0.0 上限 = 3.01239983138e-182 解 = 1.50619991569e-182
# 下限 = 0.0 上限 = 1.50619991569e-182 解 = 7.53099957845e-183
# 下限 = 0.0 上限 = 7.53099957845e-183 解 = 3.76549978922e-183
# 下限 = 0.0 上限 = 3.76549978922e-183 解 = 1.88274989461e-183
# 下限 = 0.0 上限 = 1.88274989461e-183 解 = 9.41374947306e-184
# 下限 = 0.0 上限 = 9.41374947306e-184 解 = 4.70687473653e-184
# 下限 = 0.0 上限 = 4.70687473653e-184 解 = 2.35343736826e-184
# 下限 = 0.0 上限 = 2.35343736826e-184 解 = 1.17671868413e-184
# 下限 = 0.0 上限 = 1.17671868413e-184 解 = 5.88359342066e-185
# 下限 = 0.0 上限 = 5.88359342066e-185 解 = 2.94179671033e-185
# 下限 = 0.0 上限 = 2.94179671033e-185 解 = 1.47089835517e-185
# 下限 = 0.0 上限 = 1.47089835517e-185 解 = 7.35449177583e-186
# 下限 = 0.0 上限 = 7.35449177583e-186 解 = 3.67724588791e-186
# 下限 = 0.0 上限 = 3.67724588791e-186 解 = 1.83862294396e-186
# 下限 = 0.0 上限 = 1.83862294396e-186 解 = 9.19311471978e-187
# 下限 = 0.0 上限 = 9.19311471978e-187 解 = 4.59655735989e-187
# 下限 = 0.0 上限 = 4.59655735989e-187 解 = 2.29827867995e-187
# 下限 = 0.0 上限 = 2.29827867995e-187 解 = 1.14913933997e-187
# 下限 = 0.0 上限 = 1.14913933997e-187 解 = 5.74569669986e-188
# 下限 = 0.0 上限 = 5.74569669986e-188 解 = 2.87284834993e-188
# 下限 = 0.0 上限 = 2.87284834993e-188 解 = 1.43642417497e-188
# 下限 = 0.0 上限 = 1.43642417497e-188 解 = 7.18212087483e-189
# 下限 = 0.0 上限 = 7.18212087483e-189 解 = 3.59106043742e-189
# 下限 = 0.0 上限 = 3.59106043742e-189 解 = 1.79553021871e-189
# 下限 = 0.0 上限 = 1.79553021871e-189 解 = 8.97765109354e-190
# 下限 = 0.0 上限 = 8.97765109354e-190 解 = 4.48882554677e-190
# 下限 = 0.0 上限 = 4.48882554677e-190 解 = 2.24441277338e-190
# 下限 = 0.0 上限 = 2.24441277338e-190 解 = 1.12220638669e-190
# 下限 = 0.0 上限 = 1.12220638669e-190 解 = 5.61103193346e-191
# 下限 = 0.0 上限 = 5.61103193346e-191 解 = 2.80551596673e-191
# 下限 = 0.0 上限 = 2.80551596673e-191 解 = 1.40275798337e-191
# 下限 = 0.0 上限 = 1.40275798337e-191 解 = 7.01378991683e-192
# 下限 = 0.0 上限 = 7.01378991683e-192 解 = 3.50689495841e-192
# 下限 = 0.0 上限 = 3.50689495841e-192 解 = 1.75344747921e-192
# 下限 = 0.0 上限 = 1.75344747921e-192 解 = 8.76723739603e-193
# 下限 = 0.0 上限 = 8.76723739603e-193 解 = 4.38361869802e-193
# 下限 = 0.0 上限 = 4.38361869802e-193 解 = 2.19180934901e-193
# 下限 = 0.0 上限 = 2.19180934901e-193 解 = 1.0959046745e-193
# 下限 = 0.0 上限 = 1.0959046745e-193 解 = 5.47952337252e-194
# 下限 = 0.0 上限 = 5.47952337252e-194 解 = 2.73976168626e-194
# 下限 = 0.0 上限 = 2.73976168626e-194 解 = 1.36988084313e-194
# 下限 = 0.0 上限 = 1.36988084313e-194 解 = 6.84940421565e-195
# 下限 = 0.0 上限 = 6.84940421565e-195 解 = 3.42470210783e-195
# 下限 = 0.0 上限 = 3.42470210783e-195 解 = 1.71235105391e-195
# 下限 = 0.0 上限 = 1.71235105391e-195 解 = 8.56175526956e-196
# 下限 = 0.0 上限 = 8.56175526956e-196 解 = 4.28087763478e-196
# 下限 = 0.0 上限 = 4.28087763478e-196 解 = 2.14043881739e-196
# 下限 = 0.0 上限 = 2.14043881739e-196 解 = 1.0702194087e-196
# 下限 = 0.0 上限 = 1.0702194087e-196 解 = 5.35109704348e-197
# 下限 = 0.0 上限 = 5.35109704348e-197 解 = 2.67554852174e-197
# 下限 = 0.0 上限 = 2.67554852174e-197 解 = 1.33777426087e-197
# 下限 = 0.0 上限 = 1.33777426087e-197 解 = 6.68887130435e-198
# 下限 = 0.0 上限 = 6.68887130435e-198 解 = 3.34443565217e-198
# 下限 = 0.0 上限 = 3.34443565217e-198 解 = 1.67221782609e-198
# 下限 = 0.0 上限 = 1.67221782609e-198 解 = 8.36108913043e-199
# 下限 = 0.0 上限 = 8.36108913043e-199 解 = 4.18054456522e-199
# 下限 = 0.0 上限 = 4.18054456522e-199 解 = 2.09027228261e-199
# 下限 = 0.0 上限 = 2.09027228261e-199 解 = 1.0451361413e-199
# 下限 = 0.0 上限 = 1.0451361413e-199 解 = 5.22568070652e-200
# 下限 = 0.0 上限 = 5.22568070652e-200 解 = 2.61284035326e-200
# 下限 = 0.0 上限 = 2.61284035326e-200 解 = 1.30642017663e-200
# 下限 = 0.0 上限 = 1.30642017663e-200 解 = 6.53210088315e-201
# 下限 = 0.0 上限 = 6.53210088315e-201 解 = 3.26605044158e-201
# 下限 = 0.0 上限 = 3.26605044158e-201 解 = 1.63302522079e-201
# 下限 = 0.0 上限 = 1.63302522079e-201 解 = 8.16512610394e-202
# 下限 = 0.0 上限 = 8.16512610394e-202 解 = 4.08256305197e-202
# 下限 = 0.0 上限 = 4.08256305197e-202 解 = 2.04128152598e-202
# 下限 = 0.0 上限 = 2.04128152598e-202 解 = 1.02064076299e-202
# 下限 = 0.0 上限 = 1.02064076299e-202 解 = 5.10320381496e-203
# 下限 = 0.0 上限 = 5.10320381496e-203 解 = 2.55160190748e-203
# 下限 = 0.0 上限 = 2.55160190748e-203 解 = 1.27580095374e-203
# 下限 = 0.0 上限 = 1.27580095374e-203 解 = 6.3790047687e-204
# 下限 = 0.0 上限 = 6.3790047687e-204 解 = 3.18950238435e-204
# 下限 = 0.0 上限 = 3.18950238435e-204 解 = 1.59475119218e-204
# 下限 = 0.0 上限 = 1.59475119218e-204 解 = 7.97375596088e-205
# 下限 = 0.0 上限 = 7.97375596088e-205 解 = 3.98687798044e-205
# 下限 = 0.0 上限 = 3.98687798044e-205 解 = 1.99343899022e-205
# 下限 = 0.0 上限 = 1.99343899022e-205 解 = 9.9671949511e-206
# 下限 = 0.0 上限 = 9.9671949511e-206 解 = 4.98359747555e-206
# 下限 = 0.0 上限 = 4.98359747555e-206 解 = 2.49179873777e-206
# 下限 = 0.0 上限 = 2.49179873777e-206 解 = 1.24589936889e-206
# 下限 = 0.0 上限 = 1.24589936889e-206 解 = 6.22949684444e-207
# 下限 = 0.0 上限 = 6.22949684444e-207 解 = 3.11474842222e-207
# 下限 = 0.0 上限 = 3.11474842222e-207 解 = 1.55737421111e-207
# 下限 = 0.0 上限 = 1.55737421111e-207 解 = 7.78687105554e-208
# 下限 = 0.0 上限 = 7.78687105554e-208 解 = 3.89343552777e-208
# 下限 = 0.0 上限 = 3.89343552777e-208 解 = 1.94671776389e-208
# 下限 = 0.0 上限 = 1.94671776389e-208 解 = 9.73358881943e-209
# 下限 = 0.0 上限 = 9.73358881943e-209 解 = 4.86679440972e-209
# 下限 = 0.0 上限 = 4.86679440972e-209 解 = 2.43339720486e-209
# 下限 = 0.0 上限 = 2.43339720486e-209 解 = 1.21669860243e-209
# 下限 = 0.0 上限 = 1.21669860243e-209 解 = 6.08349301214e-210
# 下限 = 0.0 上限 = 6.08349301214e-210 解 = 3.04174650607e-210
# 下限 = 0.0 上限 = 3.04174650607e-210 解 = 1.52087325304e-210
# 下限 = 0.0 上限 = 1.52087325304e-210 解 = 7.60436626518e-211
# 下限 = 0.0 上限 = 7.60436626518e-211 解 = 3.80218313259e-211
# 下限 = 0.0 上限 = 3.80218313259e-211 解 = 1.9010915663e-211
# 下限 = 0.0 上限 = 1.9010915663e-211 解 = 9.50545783148e-212
# 下限 = 0.0 上限 = 9.50545783148e-212 解 = 4.75272891574e-212
# 下限 = 0.0 上限 = 4.75272891574e-212 解 = 2.37636445787e-212
# 下限 = 0.0 上限 = 2.37636445787e-212 解 = 1.18818222893e-212
# 下限 = 0.0 上限 = 1.18818222893e-212 解 = 5.94091114467e-213
# 下限 = 0.0 上限 = 5.94091114467e-213 解 = 2.97045557234e-213
# 下限 = 0.0 上限 = 2.97045557234e-213 解 = 1.48522778617e-213
# 下限 = 0.0 上限 = 1.48522778617e-213 解 = 7.42613893084e-214
# 下限 = 0.0 上限 = 7.42613893084e-214 解 = 3.71306946542e-214
# 下限 = 0.0 上限 = 3.71306946542e-214 解 = 1.85653473271e-214
# 下限 = 0.0 上限 = 1.85653473271e-214 解 = 9.28267366355e-215
# 下限 = 0.0 上限 = 9.28267366355e-215 解 = 4.64133683178e-215
# 下限 = 0.0 上限 = 4.64133683178e-215 解 = 2.32066841589e-215
# 下限 = 0.0 上限 = 2.32066841589e-215 解 = 1.16033420794e-215
# 下限 = 0.0 上限 = 1.16033420794e-215 解 = 5.80167103972e-216
# 下限 = 0.0 上限 = 5.80167103972e-216 解 = 2.90083551986e-216
# 下限 = 0.0 上限 = 2.90083551986e-216 解 = 1.45041775993e-216
# 下限 = 0.0 上限 = 1.45041775993e-216 解 = 7.25208879965e-217
# 下限 = 0.0 上限 = 7.25208879965e-217 解 = 3.62604439982e-217
# 下限 = 0.0 上限 = 3.62604439982e-217 解 = 1.81302219991e-217
# 下限 = 0.0 上限 = 1.81302219991e-217 解 = 9.06511099956e-218
# 下限 = 0.0 上限 = 9.06511099956e-218 解 = 4.53255549978e-218
# 下限 = 0.0 上限 = 4.53255549978e-218 解 = 2.26627774989e-218
# 下限 = 0.0 上限 = 2.26627774989e-218 解 = 1.13313887495e-218
# 下限 = 0.0 上限 = 1.13313887495e-218 解 = 5.66569437473e-219
# 下限 = 0.0 上限 = 5.66569437473e-219 解 = 2.83284718736e-219
# 下限 = 0.0 上限 = 2.83284718736e-219 解 = 1.41642359368e-219
# 下限 = 0.0 上限 = 1.41642359368e-219 解 = 7.08211796841e-220
# 下限 = 0.0 上限 = 7.08211796841e-220 解 = 3.5410589842e-220
# 下限 = 0.0 上限 = 3.5410589842e-220 解 = 1.7705294921e-220
# 下限 = 0.0 上限 = 1.7705294921e-220 解 = 8.85264746051e-221
# 下限 = 0.0 上限 = 8.85264746051e-221 解 = 4.42632373025e-221
# 下限 = 0.0 上限 = 4.42632373025e-221 解 = 2.21316186513e-221
# 下限 = 0.0 上限 = 2.21316186513e-221 解 = 1.10658093256e-221
# 下限 = 0.0 上限 = 1.10658093256e-221 解 = 5.53290466282e-222
# 下限 = 0.0 上限 = 5.53290466282e-222 解 = 2.76645233141e-222
# 下限 = 0.0 上限 = 2.76645233141e-222 解 = 1.3832261657e-222
# 下限 = 0.0 上限 = 1.3832261657e-222 解 = 6.91613082852e-223
# 下限 = 0.0 上限 = 6.91613082852e-223 解 = 3.45806541426e-223
# 下限 = 0.0 上限 = 3.45806541426e-223 解 = 1.72903270713e-223
# 下限 = 0.0 上限 = 1.72903270713e-223 解 = 8.64516353565e-224
# 下限 = 0.0 上限 = 8.64516353565e-224 解 = 4.32258176783e-224
# 下限 = 0.0 上限 = 4.32258176783e-224 解 = 2.16129088391e-224
# 下限 = 0.0 上限 = 2.16129088391e-224 解 = 1.08064544196e-224
# 下限 = 0.0 上限 = 1.08064544196e-224 解 = 5.40322720978e-225
# 下限 = 0.0 上限 = 5.40322720978e-225 解 = 2.70161360489e-225
# 下限 = 0.0 上限 = 2.70161360489e-225 解 = 1.35080680245e-225
# 下限 = 0.0 上限 = 1.35080680245e-225 解 = 6.75403401223e-226
# 下限 = 0.0 上限 = 6.75403401223e-226 解 = 3.37701700611e-226
# 下限 = 0.0 上限 = 3.37701700611e-226 解 = 1.68850850306e-226
# 下限 = 0.0 上限 = 1.68850850306e-226 解 = 8.44254251529e-227
# 下限 = 0.0 上限 = 8.44254251529e-227 解 = 4.22127125764e-227
# 下限 = 0.0 上限 = 4.22127125764e-227 解 = 2.11063562882e-227
# 下限 = 0.0 上限 = 2.11063562882e-227 解 = 1.05531781441e-227
# 下限 = 0.0 上限 = 1.05531781441e-227 解 = 5.27658907205e-228
# 下限 = 0.0 上限 = 5.27658907205e-228 解 = 2.63829453603e-228
# 下限 = 0.0 上限 = 2.63829453603e-228 解 = 1.31914726801e-228
# 下限 = 0.0 上限 = 1.31914726801e-228 解 = 6.59573634007e-229
# 下限 = 0.0 上限 = 6.59573634007e-229 解 = 3.29786817003e-229
# 下限 = 0.0 上限 = 3.29786817003e-229 解 = 1.64893408502e-229
# 下限 = 0.0 上限 = 1.64893408502e-229 解 = 8.24467042508e-230
# 下限 = 0.0 上限 = 8.24467042508e-230 解 = 4.12233521254e-230
# 下限 = 0.0 上限 = 4.12233521254e-230 解 = 2.06116760627e-230
# 下限 = 0.0 上限 = 2.06116760627e-230 解 = 1.03058380314e-230
# 下限 = 0.0 上限 = 1.03058380314e-230 解 = 5.15291901568e-231
# 下限 = 0.0 上限 = 5.15291901568e-231 解 = 2.57645950784e-231
# 下限 = 0.0 上限 = 2.57645950784e-231 解 = 1.28822975392e-231
# 下限 = 0.0 上限 = 1.28822975392e-231 解 = 6.4411487696e-232
# 下限 = 0.0 上限 = 6.4411487696e-232 解 = 3.2205743848e-232
# 下限 = 0.0 上限 = 3.2205743848e-232 解 = 1.6102871924e-232
# 下限 = 0.0 上限 = 1.6102871924e-232 解 = 8.051435962e-233
# 下限 = 0.0 上限 = 8.051435962e-233 解 = 4.025717981e-233
# 下限 = 0.0 上限 = 4.025717981e-233 解 = 2.0128589905e-233
# 下限 = 0.0 上限 = 2.0128589905e-233 解 = 1.00642949525e-233
# 下限 = 0.0 上限 = 1.00642949525e-233 解 = 5.03214747625e-234
# 下限 = 0.0 上限 = 5.03214747625e-234 解 = 2.51607373812e-234
# 下限 = 0.0 上限 = 2.51607373812e-234 解 = 1.25803686906e-234
# 下限 = 0.0 上限 = 1.25803686906e-234 解 = 6.29018434531e-235
# 下限 = 0.0 上限 = 6.29018434531e-235 解 = 3.14509217265e-235
# 下限 = 0.0 上限 = 3.14509217265e-235 解 = 1.57254608633e-235
# 下限 = 0.0 上限 = 1.57254608633e-235 解 = 7.86273043164e-236
# 下限 = 0.0 上限 = 7.86273043164e-236 解 = 3.93136521582e-236
# 下限 = 0.0 上限 = 3.93136521582e-236 解 = 1.96568260791e-236
# 下限 = 0.0 上限 = 1.96568260791e-236 解 = 9.82841303955e-237
# 下限 = 0.0 上限 = 9.82841303955e-237 解 = 4.91420651977e-237
# 下限 = 0.0 上限 = 4.91420651977e-237 解 = 2.45710325989e-237
# 下限 = 0.0 上限 = 2.45710325989e-237 解 = 1.22855162994e-237
# 下限 = 0.0 上限 = 1.22855162994e-237 解 = 6.14275814972e-238
# 下限 = 0.0 上限 = 6.14275814972e-238 解 = 3.07137907486e-238
# 下限 = 0.0 上限 = 3.07137907486e-238 解 = 1.53568953743e-238
# 下限 = 0.0 上限 = 1.53568953743e-238 解 = 7.67844768715e-239
# 下限 = 0.0 上限 = 7.67844768715e-239 解 = 3.83922384357e-239
# 下限 = 0.0 上限 = 3.83922384357e-239 解 = 1.91961192179e-239
# 下限 = 0.0 上限 = 1.91961192179e-239 解 = 9.59805960893e-240
# 下限 = 0.0 上限 = 9.59805960893e-240 解 = 4.79902980447e-240
# 下限 = 0.0 上限 = 4.79902980447e-240 解 = 2.39951490223e-240
# 下限 = 0.0 上限 = 2.39951490223e-240 解 = 1.19975745112e-240
# 下限 = 0.0 上限 = 1.19975745112e-240 解 = 5.99878725558e-241
# 下限 = 0.0 上限 = 5.99878725558e-241 解 = 2.99939362779e-241
# 下限 = 0.0 上限 = 2.99939362779e-241 解 = 1.4996968139e-241
# 下限 = 0.0 上限 = 1.4996968139e-241 解 = 7.49848406948e-242
# 下限 = 0.0 上限 = 7.49848406948e-242 解 = 3.74924203474e-242
# 下限 = 0.0 上限 = 3.74924203474e-242 解 = 1.87462101737e-242
# 下限 = 0.0 上限 = 1.87462101737e-242 解 = 9.37310508685e-243
# 下限 = 0.0 上限 = 9.37310508685e-243 解 = 4.68655254342e-243
# 下限 = 0.0 上限 = 4.68655254342e-243 解 = 2.34327627171e-243
# 下限 = 0.0 上限 = 2.34327627171e-243 解 = 1.17163813586e-243
# 下限 = 0.0 上限 = 1.17163813586e-243 解 = 5.85819067928e-244
# 下限 = 0.0 上限 = 5.85819067928e-244 解 = 2.92909533964e-244
# 下限 = 0.0 上限 = 2.92909533964e-244 解 = 1.46454766982e-244
# 下限 = 0.0 上限 = 1.46454766982e-244 解 = 7.3227383491e-245
# 下限 = 0.0 上限 = 7.3227383491e-245 解 = 3.66136917455e-245
# 下限 = 0.0 上限 = 3.66136917455e-245 解 = 1.83068458727e-245
# 下限 = 0.0 上限 = 1.83068458727e-245 解 = 9.15342293637e-246
# 下限 = 0.0 上限 = 9.15342293637e-246 解 = 4.57671146819e-246
# 下限 = 0.0 上限 = 4.57671146819e-246 解 = 2.28835573409e-246
# 下限 = 0.0 上限 = 2.28835573409e-246 解 = 1.14417786705e-246
# 下限 = 0.0 上限 = 1.14417786705e-246 解 = 5.72088933523e-247
# 下限 = 0.0 上限 = 5.72088933523e-247 解 = 2.86044466762e-247
# 下限 = 0.0 上限 = 2.86044466762e-247 解 = 1.43022233381e-247
# 下限 = 0.0 上限 = 1.43022233381e-247 解 = 7.15111166904e-248
# 下限 = 0.0 上限 = 7.15111166904e-248 解 = 3.57555583452e-248
# 下限 = 0.0 上限 = 3.57555583452e-248 解 = 1.78777791726e-248
# 下限 = 0.0 上限 = 1.78777791726e-248 解 = 8.9388895863e-249
# 下限 = 0.0 上限 = 8.9388895863e-249 解 = 4.46944479315e-249
# 下限 = 0.0 上限 = 4.46944479315e-249 解 = 2.23472239658e-249
# 下限 = 0.0 上限 = 2.23472239658e-249 解 = 1.11736119829e-249
# 下限 = 0.0 上限 = 1.11736119829e-249 解 = 5.58680599144e-250
# 下限 = 0.0 上限 = 5.58680599144e-250 解 = 2.79340299572e-250
# 下限 = 0.0 上限 = 2.79340299572e-250 解 = 1.39670149786e-250
# 下限 = 0.0 上限 = 1.39670149786e-250 解 = 6.9835074893e-251
# 下限 = 0.0 上限 = 6.9835074893e-251 解 = 3.49175374465e-251
# 下限 = 0.0 上限 = 3.49175374465e-251 解 = 1.74587687232e-251
# 下限 = 0.0 上限 = 1.74587687232e-251 解 = 8.72938436162e-252
# 下限 = 0.0 上限 = 8.72938436162e-252 解 = 4.36469218081e-252
# 下限 = 0.0 上限 = 4.36469218081e-252 解 = 2.18234609041e-252
# 下限 = 0.0 上限 = 2.18234609041e-252 解 = 1.0911730452e-252
# 下限 = 0.0 上限 = 1.0911730452e-252 解 = 5.45586522602e-253
# 下限 = 0.0 上限 = 5.45586522602e-253 解 = 2.72793261301e-253
# 下限 = 0.0 上限 = 2.72793261301e-253 解 = 1.3639663065e-253
# 下限 = 0.0 上限 = 1.3639663065e-253 解 = 6.81983153252e-254
# 下限 = 0.0 上限 = 6.81983153252e-254 解 = 3.40991576626e-254
# 下限 = 0.0 上限 = 3.40991576626e-254 解 = 1.70495788313e-254
# 下限 = 0.0 上限 = 1.70495788313e-254 解 = 8.52478941565e-255
# 下限 = 0.0 上限 = 8.52478941565e-255 解 = 4.26239470782e-255
# 下限 = 0.0 上限 = 4.26239470782e-255 解 = 2.13119735391e-255
# 下限 = 0.0 上限 = 2.13119735391e-255 解 = 1.06559867696e-255
# 下限 = 0.0 上限 = 1.06559867696e-255 解 = 5.32799338478e-256
# 下限 = 0.0 上限 = 5.32799338478e-256 解 = 2.66399669239e-256
# 下限 = 0.0 上限 = 2.66399669239e-256 解 = 1.3319983462e-256
# 下限 = 0.0 上限 = 1.3319983462e-256 解 = 6.65999173098e-257
# 下限 = 0.0 上限 = 6.65999173098e-257 解 = 3.32999586549e-257
# 下限 = 0.0 上限 = 3.32999586549e-257 解 = 1.66499793274e-257
# 下限 = 0.0 上限 = 1.66499793274e-257 解 = 8.32498966372e-258
# 下限 = 0.0 上限 = 8.32498966372e-258 解 = 4.16249483186e-258
# 下限 = 0.0 上限 = 4.16249483186e-258 解 = 2.08124741593e-258
# 下限 = 0.0 上限 = 2.08124741593e-258 解 = 1.04062370796e-258
# 下限 = 0.0 上限 = 1.04062370796e-258 解 = 5.20311853982e-259
# 下限 = 0.0 上限 = 5.20311853982e-259 解 = 2.60155926991e-259
# 下限 = 0.0 上限 = 2.60155926991e-259 解 = 1.30077963496e-259
# 下限 = 0.0 上限 = 1.30077963496e-259 解 = 6.50389817478e-260
# 下限 = 0.0 上限 = 6.50389817478e-260 解 = 3.25194908739e-260
# 下限 = 0.0 上限 = 3.25194908739e-260 解 = 1.6259745437e-260
# 下限 = 0.0 上限 = 1.6259745437e-260 解 = 8.12987271848e-261
# 下限 = 0.0 上限 = 8.12987271848e-261 解 = 4.06493635924e-261
# 下限 = 0.0 上限 = 4.06493635924e-261 解 = 2.03246817962e-261
# 下限 = 0.0 上限 = 2.03246817962e-261 解 = 1.01623408981e-261
# 下限 = 0.0 上限 = 1.01623408981e-261 解 = 5.08117044905e-262
# 下限 = 0.0 上限 = 5.08117044905e-262 解 = 2.54058522452e-262
# 下限 = 0.0 上限 = 2.54058522452e-262 解 = 1.27029261226e-262
# 下限 = 0.0 上限 = 1.27029261226e-262 解 = 6.35146306131e-263
# 下限 = 0.0 上限 = 6.35146306131e-263 解 = 3.17573153065e-263
# 下限 = 0.0 上限 = 3.17573153065e-263 解 = 1.58786576533e-263
# 下限 = 0.0 上限 = 1.58786576533e-263 解 = 7.93932882664e-264
# 下限 = 0.0 上限 = 7.93932882664e-264 解 = 3.96966441332e-264
# 下限 = 0.0 上限 = 3.96966441332e-264 解 = 1.98483220666e-264
# ...
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# 下限 = 0.0 上限 = 0.0 解 = 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-62457277ba51> in <module>()
#       7 ans = (high + low) / 2.0
#       8 while abs(ans ** 2 - x) >= epsilon:
# ----> 9     print '下限 =', low, '上限 =', high, '解 =', ans
#      10     numGuesses += 1
#      11     if ans**2 < x:
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     374             is_child = (not self._is_master_process())
#     375             # only touch the buffer in the IO thread to avoid races
# --> 376             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     377             if is_child:
#     378                 # newlines imply flush in subprocesses
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/ipykernel/iostream.pyc in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/zmq/sugar/socket.pyc in send(self, data, flags, copy, track, routing_id, group)
#     389                                  copy_threshold=self.copy_threshold)
#     390             data.group = group
# --> 391         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     392
#     393     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /Users/kokubo/.pyenv/versions/2.7.15/lib/python2.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#      10     """
#      11     cdef int errno = zmq_errno()
# ---> 12     PyErr_CheckSignals()
#      13     if rc == -1: # if rc < -1, it's a bug in libzmq. Should we warn?
#      14         if errno == EINTR:
#
# KeyboardInterrupt:

# %%
# 指練習
x = -257
epsilon = 0.01
numGuesses = 0
low = min(-1.0, x)
high = max(1.0, x)
ans = (high + low) / 2.0
while abs(ans**3 - x) >= epsilon:
    print '下限 =', low, '上限 =', high, '解 =', ans
    numGuesses += 1
    if ans**3 < x:
        low = ans
    else:
        high = ans
    ans = (high + low) / 2.0

print '試行回数 =', numGuesses
print str(x) + 'の立方根の近似解は' + str(ans)
# Out:
# 下限 = -257 上限 = 1.0 解 = -128.0
# 下限 = -128.0 上限 = 1.0 解 = -63.5
# 下限 = -63.5 上限 = 1.0 解 = -31.25
# 下限 = -31.25 上限 = 1.0 解 = -15.125
# 下限 = -15.125 上限 = 1.0 解 = -7.0625
# 下限 = -7.0625 上限 = 1.0 解 = -3.03125
# 下限 = -7.0625 上限 = -3.03125 解 = -5.046875
# 下限 = -7.0625 上限 = -5.046875 解 = -6.0546875
# 下限 = -7.0625 上限 = -6.0546875 解 = -6.55859375
# 下限 = -6.55859375 上限 = -6.0546875 解 = -6.306640625
# 下限 = -6.55859375 上限 = -6.306640625 解 = -6.4326171875
# 下限 = -6.4326171875 上限 = -6.306640625 解 = -6.36962890625
# 下限 = -6.36962890625 上限 = -6.306640625 解 = -6.33813476562
# 下限 = -6.36962890625 上限 = -6.33813476562 解 = -6.35388183594
# 下限 = -6.36962890625 上限 = -6.35388183594 解 = -6.36175537109
# 試行回数 = 15
# -257の立方根の近似解は-6.35781860352

# %%
x = 0.0
for i in range (10):
    x = x + 0.1
if x == 1.0:
    print x, '= 1.0'
else :
    print x, 'は1.0ではない'
# Out:
# 1.0 は1.0ではない

# %% [raw]
# p.37

# %%
# 平方根を求めるためのニュートン=ラフソン法
# x**2 - kがepsilon以内になるようなxを求める

k = 24.0 # 平方根を求めたい数

epsilon = 0.01 # 精度
guess = k / 2.0 # 試行解
while abs(guess * guess - k) >= epsilon:
    guess = guess - (((guess ** 2) - k) / (2 * guess))

print str(k) + 'の平方根はおよそ' + str(guess) +'です'
# Out:
# 24.0の平方根はおよそ4.89898874321です

# %%
# 指練習
# 平方根を求めるためのニュートン=ラフソン法
# x**2 - kがepsilon以内になるようなxを求める

k = 24.0 # 平方根を求めたい数

epsilon = 0.01 # 精度
numGuess = 0 # 試行回数
guess = k / 2.0 # 試行解
while abs(guess * guess - k) >= epsilon:
    numGuess += 1
    guess = guess - (((guess ** 2) - k) / (2 * guess))

print '試行回数:' + str(numGuess)
print str(k) + 'の平方根はおよそ' + str(guess) + 'です'
# Out:
# 試行回数:4
# 24.0の平方根はおよそ4.89898874321です

# %%
# 指練習
# 平方根を求めるための二分法とニュートン=ラフソン法の比較
# x**2 - kがepsilon以内になるようなxを求める

k = 24.0 # 平方根を求めたい数
epsilon = 0.01 # 精度

numGuesses = 0
low = 0.0
high = max(1.0, k)
ans = (high + low) / 2.0
while abs(ans**2 - k) >= epsilon:
    numGuesses += 1
    if ans**2 < k:
        low = ans
    else:
        high = ans
    ans = (high + low) / 2.0
print '二分法'
print '試行回数:' + str(numGuesses)
print str(k) + 'の平方根はおよそ' + str(ans)

numGuess = 0
guess = k / 2.0
while abs(guess * guess - k) >= epsilon:
    numGuess += 1
    guess = guess - (((guess**2) - k) / (2*guess))
print 'ニュートン=ラフソン法'
print '試行回数:' + str(numGuess)
print str(k) + 'の平方根はおよそ' + str(guess) + 'です'
# Out:
# 二分法
# 試行回数:9
# 24.0の平方根はおよそ4.8984375
# ニュートン=ラフソン法
# 試行回数:4
# 24.0の平方根はおよそ4.89898874321です
